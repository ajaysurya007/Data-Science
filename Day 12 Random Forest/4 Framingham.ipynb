# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sea

# %%
df = pd.read_csv(r'C:\Users\user\Downloads\C4_framingham.csv')
df
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df['prevalentHyp'].value_counts()
# Out:
# 0    2922
# 1    1316
# Name: prevalentHyp, dtype: int64

# %%
x = df.drop('prevalentHyp',axis=1)
y=df['prevalentHyp']

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df.columns
# Out:
# Index(['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
#        'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
#        'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD'],
#       dtype='object')

# %%
df1 = df[['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
       'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
       'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD']]
df1
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     NaN
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
df1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4238 entries, 0 to 4237
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   male             4238 non-null   int64
#  1   age              4238 non-null   int64
#  2   education        4133 non-null   float64
#  3   currentSmoker    4238 non-null   int64
#  4   cigsPerDay       4209 non-null   float64
#  5   BPMeds           4185 non-null   float64
#  6   prevalentStroke  4238 non-null   int64
#  7   prevalentHyp     4238 non-null   int64
#  8   diabetes         4238 non-null   int64
#  9   totChol          4188 non-null   float64
#  10  sysBP            4238 non-null   float64
#  11  diaBP            4238 non-null   float64
#  12  BMI              4219 non-null   float64
#  13  heartRate        4237 non-null   float64
#  14  glucose          3850 non-null   float64
#  15  TenYearCHD       4238 non-null   int64
# dtypes: float64(9), int64(7)
# ...

# %%
df2 = df1.fillna(0)

# %%
x = df2[['male', 'age', 'education', 'currentSmoker', 'cigsPerDay', 'BPMeds',
       'prevalentStroke', 'prevalentHyp', 'diabetes', 'totChol', 'sysBP',
       'diaBP', 'BMI', 'heartRate', 'glucose', 'TenYearCHD']]
y = df2['prevalentHyp']

# %%
g1 = {"prevalentHyp":{'0':1,'1':2}}
df2= df2.replace(g1)
print(df2)
# Out:
#       male  age  education  currentSmoker  cigsPerDay  BPMeds  \
# 0        1   39        4.0              0         0.0     0.0
# 1        0   46        2.0              0         0.0     0.0
# 2        1   48        1.0              1        20.0     0.0
# 3        0   61        3.0              1        30.0     0.0
# 4        0   46        3.0              1        23.0     0.0
# ...    ...  ...        ...            ...         ...     ...
# 4233     1   50        1.0              1         1.0     0.0
# 4234     1   51        3.0              1        43.0     0.0
# 4235     0   48        2.0              1        20.0     0.0
# 4236     0   44        1.0              1        15.0     0.0
# 4237     0   52        2.0              0         0.0     0.0
#
#       prevalentStroke  prevalentHyp  diabetes  totChol  sysBP  diaBP    BMI  \
# 0                   0             0         0    195.0  106.0   70.0  26.97
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,train_size=0.70)

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
y_train.shape
# Out:
# (2966,)

# %%
rfc = RandomForestClassifier()
rfc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
parameters = {
    'max_depth':[13,24,53,64,25],
    'min_samples_leaf':[35,16,75,70,45],
    'n_estimators':[10,20,30,40,50]
}

# %%
from sklearn.model_selection import GridSearchCV

# %%
grid_search = GridSearchCV(estimator=rfc,param_grid=parameters,cv=2,scoring='accuracy')
grid_search.fit(x_train,y_train)
# Out:
# GridSearchCV(cv=2, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [13, 24, 53, 64, 25],
#                          'min_samples_leaf': [35, 16, 75, 70, 45],
#                          'n_estimators': [10, 20, 30, 40, 50]},
#              scoring='accuracy')

# %%
grid_search.best_score_
# Out:
# 1.0

# %%
from sklearn.tree import plot_tree

# %%
rfc_best= grid_search.best_estimator_

# %%
plt.figure(figsize=(80,40))
plot_tree(rfc_best.estimators_[5],feature_names=x.columns,class_names=["Yes","No"],filled=True)
# Out:
# [Text(1302.0, 2019.0857142857144, 'sysBP <= 139.25\ngini = 0.43\nsamples = 1882\nvalue = [2039, 927]\nclass = Yes'),
#  Text(425.14285714285717, 1708.457142857143, 'prevalentHyp <= 0.5\ngini = 0.134\nsamples = 1288\nvalue = [1882, 146]\nclass = Yes'),
#  Text(212.57142857142858, 1397.8285714285716, 'gini = 0.0\nsamples = 1194\nvalue = [1882, 0]\nclass = Yes'),
#  Text(637.7142857142858, 1397.8285714285716, 'gini = 0.0\nsamples = 94\nvalue = [0, 146]\nclass = No'),
#  Text(2178.857142857143, 1708.457142857143, 'sysBP <= 147.75\ngini = 0.279\nsamples = 594\nvalue = [157, 781]\nclass = No'),
#  Text(1062.857142857143, 1397.8285714285716, 'heartRate <= 78.5\ngini = 0.454\nsamples = 198\nvalue = [105, 197]\nclass = No'),
#  Text(637.7142857142858, 1087.2, 'glucose <= 73.5\ngini = 0.367\nsamples = 120\nvalue = [44, 138]\nclass = No'),
#  Text(425.14285714285717, 776.5714285714287, 'gini = 0.254\nsamples = 45\nvalue = [10, 57]\nclass = No'),
# ...
