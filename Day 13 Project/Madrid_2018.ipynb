# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv(r"c:\Users\user\Downloads\csvs_per_year\madrid_2018.csv")
df
# Out:
#                       date  BEN   CH4   CO  EBE  NMHC     NO   NO_2    NOx  \
# 0      2018-03-01 01:00:00  NaN   NaN  0.3  NaN   NaN    1.0   29.0   31.0
# 1      2018-03-01 01:00:00  0.5  1.39  0.3  0.2  0.02    6.0   40.0   49.0
# 2      2018-03-01 01:00:00  0.4   NaN  NaN  0.2   NaN    4.0   41.0   47.0
# 3      2018-03-01 01:00:00  NaN   NaN  0.3  NaN   NaN    1.0   35.0   37.0
# 4      2018-03-01 01:00:00  NaN   NaN  NaN  NaN   NaN    1.0   27.0   29.0
# ...                    ...  ...   ...  ...  ...   ...    ...    ...    ...
# 69091  2018-02-01 00:00:00  NaN   NaN  0.5  NaN   NaN   66.0   91.0  192.0
# 69092  2018-02-01 00:00:00  NaN   NaN  0.7  NaN   NaN   87.0  107.0  241.0
# 69093  2018-02-01 00:00:00  NaN   NaN  NaN  NaN   NaN   28.0   48.0   91.0
# 69094  2018-02-01 00:00:00  NaN   NaN  NaN  NaN   NaN  141.0  103.0  320.0
# 69095  2018-02-01 00:00:00  NaN   NaN  NaN  NaN   NaN   69.0   96.0  202.0
#
#         O_3  PM10  PM25  SO_2   TCH  TOL   station
# ...

# %%
df1 = df.fillna(0)
df1
# Out:
#                       date  BEN   CH4   CO  EBE  NMHC     NO   NO_2    NOx  \
# 0      2018-03-01 01:00:00  0.0  0.00  0.3  0.0  0.00    1.0   29.0   31.0
# 1      2018-03-01 01:00:00  0.5  1.39  0.3  0.2  0.02    6.0   40.0   49.0
# 2      2018-03-01 01:00:00  0.4  0.00  0.0  0.2  0.00    4.0   41.0   47.0
# 3      2018-03-01 01:00:00  0.0  0.00  0.3  0.0  0.00    1.0   35.0   37.0
# 4      2018-03-01 01:00:00  0.0  0.00  0.0  0.0  0.00    1.0   27.0   29.0
# ...                    ...  ...   ...  ...  ...   ...    ...    ...    ...
# 69091  2018-02-01 00:00:00  0.0  0.00  0.5  0.0  0.00   66.0   91.0  192.0
# 69092  2018-02-01 00:00:00  0.0  0.00  0.7  0.0  0.00   87.0  107.0  241.0
# 69093  2018-02-01 00:00:00  0.0  0.00  0.0  0.0  0.00   28.0   48.0   91.0
# 69094  2018-02-01 00:00:00  0.0  0.00  0.0  0.0  0.00  141.0  103.0  320.0
# 69095  2018-02-01 00:00:00  0.0  0.00  0.0  0.0  0.00   69.0   96.0  202.0
#
#         O_3  PM10  PM25  SO_2   TCH  TOL   station
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 69096 entries, 0 to 69095
# Data columns (total 16 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   date     69096 non-null  object
#  1   BEN      16950 non-null  float64
#  2   CH4      8440 non-null   float64
#  3   CO       28598 non-null  float64
#  4   EBE      16949 non-null  float64
#  5   NMHC     8440 non-null   float64
#  6   NO       68826 non-null  float64
#  7   NO_2     68826 non-null  float64
#  8   NOx      68826 non-null  float64
#  9   O_3      40049 non-null  float64
#  10  PM10     36911 non-null  float64
#  11  PM25     18912 non-null  float64
#  12  SO_2     28586 non-null  float64
#  13  TCH      8440 non-null   float64
#  14  TOL      16950 non-null  float64
#  15  station  69096 non-null  int64
# dtypes: float64(14), int64(1), object(1)
# memory usage: 8.4+ MB

# %%
df.columns
# Out:
# Index(['date', 'BEN', 'CH4', 'CO', 'EBE', 'NMHC', 'NO', 'NO_2', 'NOx', 'O_3',
#        'PM10', 'PM25', 'SO_2', 'TCH', 'TOL', 'station'],
#       dtype='object')

# %%
df2=df1[['BEN', 'CO', 'EBE', 'NMHC', 'NO_2', 'NOx', 'O_3',
       'PM10', 'SO_2', 'TCH', 'TOL', 'station']]

# %%
sns.pairplot(df2)

# %%
sns.distplot(df2['O_3'])
# Out:
# C:\Users\user\anaconda3\lib\site-packages\seaborn\distributions.py:2619: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='O_3', ylabel='Density'>

# %%
sns.heatmap(df2.corr())
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Linear Regression

# %%
x = df2[['BEN', 'CO', 'EBE', 'NMHC', 'NO_2', 'NOx',
       'PM10', 'SO_2', 'TCH', 'TOL']]
y = df2['O_3']

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3)

# %%
from sklearn.linear_model import LinearRegression

lr=LinearRegression()
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(lr.intercept_)
# Out:
# 46.254634721017666

# %%
coeff=pd.DataFrame(lr.coef_,x.columns,columns=['Co-effecient'])
coeff
# Out:
#       Co-effecient
# BEN      -4.787522
# CO       18.176167
# EBE       0.741337
# NMHC   -217.214535
# NO_2     -0.587347
# NOx       0.043701
# PM10     -0.222963
# SO_2     -1.092749
# TCH      16.624280
# TOL       0.903267

# %%
prediction=lr.predict(x_test)
plt.scatter(y_test,prediction)

# %%
print(lr.score(x_test,y_test))
# Out:
# 0.2514248233350309

# %%
lr.score(x_train,y_train)
# Out:
# 0.2544719300276732

# %% [markdown]
# # Ridge Lasso

# %%
from sklearn.linear_model import Ridge,Lasso

# %%
rr=Ridge(alpha=10)
rr.fit(x_train,y_train)
rr.score(x_test,y_test)
# Out:
# 0.24891103965703265

# %%
predict2=(rr.predict(x_test))

# %%
la=Lasso(alpha=10)
la.fit(x_train,y_train)
# Out:
# Lasso(alpha=10)

# %%
la.score(x_test,y_test)
# Out:
# 0.21723018647067593

# %% [markdown]
# # Elastic Net regression

# %%
from sklearn.linear_model import ElasticNet
en=ElasticNet()
en.fit(x_train,y_train)
# Out:
# ElasticNet()

# %%
print(en.coef_)
# Out:
# [ 0.          0.30023516  0.          0.         -0.57254495  0.04759834
#  -0.21598178 -0.66894982  1.02427064  0.        ]

# %%
print(en.intercept_)
# Out:
# 47.59744242035073

# %%
print(en.score(x_test,y_test))
# Out:
# 0.2270389359285121

# %%
print(en.score(x_train,y_train))
# Out:
# 0.22790190069212357

# %% [markdown]
# # Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
feature_matrix=df2.iloc[:,0:5]
target_vector=df2.iloc[:,-1]

# %%
from sklearn.preprocessing import StandardScaler

# %%
fs=StandardScaler().fit_transform(feature_matrix)

# %%
logr=LogisticRegression()
logr.fit(fs,target_vector)
# Out:
# C:\Users\user\anaconda3\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
df2.shape
# Out:
# (69096, 12)

# %%
observation=[[1,2,3,4,5]]
predication = logr.predict(observation)

# %%
print(predication)
# Out:
# [28079008]

# %%
logr.classes_
# Out:
# array([28079004, 28079008, 28079011, 28079016, 28079017, 28079018,
#        28079024, 28079027, 28079035, 28079036, 28079038, 28079039,
#        28079040, 28079047, 28079048, 28079049, 28079050, 28079054,
#        28079055, 28079056, 28079057, 28079058, 28079059, 28079060],
#       dtype=int64)

# %%
from sklearn.model_selection import train_test_split

x_train,x_test,y_train,y_test = train_test_split(feature_matrix,target_vector,test_size=0.30)

# %%
print(logr.score(x_test,y_test))
# Out:
# 0.060012542814414586

# %%
print(logr.score(x_train,y_train))
# Out:
# 0.05696032418797941

# %% [markdown]
# # Conclusion

# %% [markdown]
# Ridge Lasso is bestfit model
#
# Linear Regression is bestfit model for dataset madrid_2001. The Score x_test,y_test is 0.27061523650744723 and x_train,y_train score is 0.2747002090644579
