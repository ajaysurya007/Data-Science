# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv(r"C:\Users\user\Downloads\rainfall in india 1901-2015.csv")
df
# Out:
#       index                SUBDIVISION  YEAR   JAN    FEB   MAR    APR    MAY  \
# 0         0  ANDAMAN & NICOBAR ISLANDS  1901  49.2   87.1  29.2    2.3  528.8
# 1         1  ANDAMAN & NICOBAR ISLANDS  1902   0.0  159.8  12.2    0.0  446.1
# 2         2  ANDAMAN & NICOBAR ISLANDS  1903  12.7  144.0   0.0    1.0  235.1
# 3         3  ANDAMAN & NICOBAR ISLANDS  1904   9.4   14.7   0.0  202.4  304.5
# 4         4  ANDAMAN & NICOBAR ISLANDS  1905   1.3    0.0   3.3   26.9  279.5
# ...     ...                        ...   ...   ...    ...   ...    ...    ...
# 4111   4111                LAKSHADWEEP  2011   5.1    2.8   3.1   85.9  107.2
# 4112   4112                LAKSHADWEEP  2012  19.2    0.1   1.6   76.8   21.2
# 4113   4113                LAKSHADWEEP  2013  26.2   34.4  37.5    5.3   88.3
# 4114   4114                LAKSHADWEEP  2014  53.2   16.1   4.4   14.9   57.4
# 4115   4115                LAKSHADWEEP  2015   2.2    0.5   3.7   87.1  133.1
#
#         JUN    JUL    AUG    SEP    OCT    NOV    DEC  ANNUAL  Jan-Feb  \
# 0     517.5  365.1  481.1  332.6  388.5  558.2   33.6  3373.2    136.3
# 1     537.1  228.9  753.7  666.2  197.2  359.0  160.5  3520.7    159.8
# 2     479.9  728.4  326.7  339.0  181.2  284.4  225.0  2957.4    156.7
# 3     495.1  502.0  160.1  820.4  222.2  308.7   40.1  3079.6     24.1
# 4     628.7  368.7  330.5  297.0  260.7   25.4  344.7  2566.7      1.3
# ...     ...    ...    ...    ...    ...    ...    ...     ...      ...
# 4111  153.6  350.2  254.0  255.2  117.4  184.3   14.9  1533.7      7.9
# 4112  327.0  231.5  381.2  179.8  145.9   12.4    8.8  1405.5     19.3
# 4113  426.2  296.4  154.4  180.0   72.8   78.1   26.7  1426.3     60.6
# 4114  244.1  116.1  466.1  132.2  169.2   59.0   62.3  1395.0     69.3
# 4115  296.6  257.5  146.4  160.4  165.4  231.0  159.0  1642.9      2.7
#
#       Mar-May  Jun-Sep  Oct-Dec
# 0       560.3   1696.3    980.3
# 1       458.3   2185.9    716.7
# 2       236.1   1874.0    690.6
# 3       506.9   1977.6    571.0
# 4       309.7   1624.9    630.8
# ...       ...      ...      ...
# 4111    196.2   1013.0    316.6
# 4112     99.6   1119.5    167.1
# 4113    131.1   1057.0    177.6
# 4114     76.7    958.5    290.5
# 4115    223.9    860.9    555.4
#
# [4116 rows x 20 columns]

# %%
df.columns
# Out:
# Index(['index', 'SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
#        'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        4116 non-null   int64
#  1   SUBDIVISION  4116 non-null   object
#  2   YEAR         4116 non-null   int64
#  3   JAN          4112 non-null   float64
#  4   FEB          4113 non-null   float64
#  5   MAR          4110 non-null   float64
#  6   APR          4112 non-null   float64
#  7   MAY          4113 non-null   float64
#  8   JUN          4111 non-null   float64
#  9   JUL          4109 non-null   float64
#  10  AUG          4112 non-null   float64
#  11  SEP          4110 non-null   float64
#  12  OCT          4109 non-null   float64
#  13  NOV          4105 non-null   float64
#  14  DEC          4106 non-null   float64
#  15  ANNUAL       4090 non-null   float64
#  16  Jan-Feb      4110 non-null   float64
#  17  Mar-May      4107 non-null   float64
#  18  Jun-Sep      4106 non-null   float64
#  19  Oct-Dec      4103 non-null   float64
# dtypes: float64(17), int64(2), object(1)
# memory usage: 643.2+ KB

# %%
df1 = df[2852:2966]
df1
# Out:
#       index SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL  \
# 2852   2852    VIDARBHA  1901  36.8  39.9  30.9  26.1   7.3  129.7  295.3
# 2853   2853    VIDARBHA  1902   1.6   0.1   0.0   6.5   4.1   38.0  270.7
# 2854   2854    VIDARBHA  1903   5.2   4.0   0.1   2.5  37.8  121.2  475.5
# 2855   2855    VIDARBHA  1904   4.3   2.4  12.9   0.2  14.8  148.9  158.3
# 2856   2856    VIDARBHA  1905   7.3  12.7  12.4  16.2  14.0   81.0  254.5
# ...     ...         ...   ...   ...   ...   ...   ...   ...    ...    ...
# 2961   2961    VIDARBHA  2010  14.0   1.9   7.5   0.3   1.9  144.8  454.5
# 2962   2962    VIDARBHA  2011   0.0   1.2   0.1   7.7   0.6  137.9  247.1
# 2963   2963    VIDARBHA  2012   3.1   0.1   0.0   0.6   0.2  125.5  370.5
# 2964   2964    VIDARBHA  2013   6.6  13.0   3.8   2.8   0.5  366.7  535.5
# 2965   2965    VIDARBHA  2014   1.2  18.3  49.6   2.6   4.0   63.3  337.6
#
#         AUG    SEP    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# 2852  368.8  123.4   35.2   0.0   0.0  1093.3     76.6     64.3    917.2
# 2853  204.7  150.9   29.6  16.1  26.7   748.9      1.7     10.6    664.3
# 2854  325.5  154.8  100.8   2.0   0.0  1229.4      9.3     40.3   1077.0
# 2855  151.8  196.9   61.7   0.0   0.9   753.2      6.7     27.9    655.9
# 2856  216.3  321.3    6.0   0.2   0.0   941.8     20.0     42.6    873.1
# ...     ...    ...    ...   ...   ...     ...      ...      ...      ...
# 2961  384.0  238.0   51.0  37.0   3.2  1338.1     15.9      9.6   1221.2
# 2962  302.8  191.0    4.7   0.0   0.0   893.2      1.2      8.4    878.8
# 2963  316.2  249.4   34.9   7.3   0.0  1107.7      3.2      0.8   1061.5
# 2964  326.1  131.7  133.5   0.0   0.0  1520.0     19.6      7.0   1360.0
# 2965  191.7  224.9   17.3   6.2   2.3   919.1     19.5     56.3    817.5
#
#       Oct-Dec
# 2852     35.2
# 2853     72.4
# 2854    102.8
# 2855     62.7
# 2856      6.2
# ...       ...
# 2961     91.3
# 2962      4.7
# 2963     42.2
# 2964    133.5
# 2965     25.8
#
# [114 rows x 20 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4116 entries, 0 to 4115
# Data columns (total 20 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   index        4116 non-null   int64
#  1   SUBDIVISION  4116 non-null   object
#  2   YEAR         4116 non-null   int64
#  3   JAN          4112 non-null   float64
#  4   FEB          4113 non-null   float64
#  5   MAR          4110 non-null   float64
#  6   APR          4112 non-null   float64
#  7   MAY          4113 non-null   float64
#  8   JUN          4111 non-null   float64
#  9   JUL          4109 non-null   float64
#  10  AUG          4112 non-null   float64
#  11  SEP          4110 non-null   float64
#  12  OCT          4109 non-null   float64
#  13  NOV          4105 non-null   float64
#  14  DEC          4106 non-null   float64
#  15  ANNUAL       4090 non-null   float64
#  16  Jan-Feb      4110 non-null   float64
#  17  Mar-May      4107 non-null   float64
#  18  Jun-Sep      4106 non-null   float64
#  19  Oct-Dec      4103 non-null   float64
# dtypes: float64(17), int64(2), object(1)
# memory usage: 643.2+ KB

# %%
df1.isna().sum()
# Out:
# index          0
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
df2 = df1.fillna(0)
df2
# Out:
#       index SUBDIVISION  YEAR   JAN   FEB   MAR   APR   MAY    JUN    JUL  \
# 2852   2852    VIDARBHA  1901  36.8  39.9  30.9  26.1   7.3  129.7  295.3
# 2853   2853    VIDARBHA  1902   1.6   0.1   0.0   6.5   4.1   38.0  270.7
# 2854   2854    VIDARBHA  1903   5.2   4.0   0.1   2.5  37.8  121.2  475.5
# 2855   2855    VIDARBHA  1904   4.3   2.4  12.9   0.2  14.8  148.9  158.3
# 2856   2856    VIDARBHA  1905   7.3  12.7  12.4  16.2  14.0   81.0  254.5
# ...     ...         ...   ...   ...   ...   ...   ...   ...    ...    ...
# 2961   2961    VIDARBHA  2010  14.0   1.9   7.5   0.3   1.9  144.8  454.5
# 2962   2962    VIDARBHA  2011   0.0   1.2   0.1   7.7   0.6  137.9  247.1
# 2963   2963    VIDARBHA  2012   3.1   0.1   0.0   0.6   0.2  125.5  370.5
# 2964   2964    VIDARBHA  2013   6.6  13.0   3.8   2.8   0.5  366.7  535.5
# 2965   2965    VIDARBHA  2014   1.2  18.3  49.6   2.6   4.0   63.3  337.6
#
#         AUG    SEP    OCT   NOV   DEC  ANNUAL  Jan-Feb  Mar-May  Jun-Sep  \
# 2852  368.8  123.4   35.2   0.0   0.0  1093.3     76.6     64.3    917.2
# 2853  204.7  150.9   29.6  16.1  26.7   748.9      1.7     10.6    664.3
# 2854  325.5  154.8  100.8   2.0   0.0  1229.4      9.3     40.3   1077.0
# 2855  151.8  196.9   61.7   0.0   0.9   753.2      6.7     27.9    655.9
# 2856  216.3  321.3    6.0   0.2   0.0   941.8     20.0     42.6    873.1
# ...     ...    ...    ...   ...   ...     ...      ...      ...      ...
# 2961  384.0  238.0   51.0  37.0   3.2  1338.1     15.9      9.6   1221.2
# 2962  302.8  191.0    4.7   0.0   0.0   893.2      1.2      8.4    878.8
# 2963  316.2  249.4   34.9   7.3   0.0  1107.7      3.2      0.8   1061.5
# 2964  326.1  131.7  133.5   0.0   0.0  1520.0     19.6      7.0   1360.0
# 2965  191.7  224.9   17.3   6.2   2.3   919.1     19.5     56.3    817.5
#
#       Oct-Dec
# 2852     35.2
# 2853     72.4
# 2854    102.8
# 2855     62.7
# 2856      6.2
# ...       ...
# 2961     91.3
# 2962      4.7
# 2963     42.2
# 2964    133.5
# 2965     25.8
#
# [114 rows x 20 columns]

# %%
df2.isna().sum()
# Out:
# index          0
# SUBDIVISION    0
# YEAR           0
# JAN            0
# FEB            0
# MAR            0
# APR            0
# MAY            0
# JUN            0
# JUL            0
# AUG            0
# SEP            0
# OCT            0
# NOV            0
# DEC            0
# ANNUAL         0
# Jan-Feb        0
# Mar-May        0
# Jun-Sep        0
# Oct-Dec        0
# dtype: int64

# %%
df2.columns
# Out:
# Index(['index', 'SUBDIVISION', 'YEAR', 'JAN', 'FEB', 'MAR', 'APR', 'MAY',
#        'JUN', 'JUL', 'AUG', 'SEP', 'OCT', 'NOV', 'DEC', 'ANNUAL', 'Jan-Feb',
#        'Mar-May', 'Jun-Sep', 'Oct-Dec'],
#       dtype='object')

# %%
df2.plot.line()
# Out:
# <AxesSubplot:>

# %%
df2.plot.bar(figsize=(13,8))
# Out:
# <AxesSubplot:>

# %%
df3 = df2['ANNUAL']

# %%
df3.plot.pie(figsize=(40,8))
# Out:
# <AxesSubplot:ylabel='ANNUAL'>

# %%
df3.plot.box(figsize=(13,8))
# Out:
# <AxesSubplot:>

# %%
df3.plot.hist(figsize=(13,8))
# Out:
# <AxesSubplot:ylabel='Frequency'>
